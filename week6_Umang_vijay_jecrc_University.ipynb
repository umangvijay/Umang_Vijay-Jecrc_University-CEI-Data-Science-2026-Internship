# %% [markdown]
# # 🧠 Week 6: Autoencoder for Image Denoising on MNIST
# **Name:** Umang Vijay | **University:** JECRC University
# **Project:** Build a deep learning model that removes noise from images using a Denoising Autoencoder
# **Dataset:** MNIST (via KaggleHub) | **Reference:** [NvsYashwanth/MNIST-Autoencoder](https://github.com/NvsYashwanth/MNIST-Autoecncoder)
#
# ---
# ## 📋 Table of Contents
# 1. Environment Setup & Imports
# 2. Dataset Loading & Preprocessing
# 3. Noise Generation & Visualization
# 4. Denoising Autoencoder Architecture
# 5. Model Training
# 6. Evaluation & Denoising Results
# 7. Bonus: Advanced Experiments
# 8. Observations & Conclusion

# %% [markdown]
# ## 1️⃣ Environment Setup & Imports
# Install and import all necessary libraries.

# %%
# Install kagglehub if not already installed
# !pip install kagglehub -q

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model, callbacks
from tensorflow.keras.datasets import mnist
import kagglehub
import os, warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU Available: {len(tf.config.list_physical_devices('GPU')) > 0}")
# Out:
# TensorFlow version: 2.20.0
# GPU Available: True

# %% [markdown]
# ## 2️⃣ Dataset Loading & Preprocessing
# Load MNIST via KaggleHub and normalize pixel values to [0, 1].

# %%
# Download MNIST dataset from KaggleHub
path = kagglehub.dataset_download("awsaf49/mnist-dataset")
print("Path to dataset files:", path)

# List downloaded files
for root, dirs, files in os.walk(path):
    for f in files:
        print(os.path.join(root, f))
# Out:
# Downloading to /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/1.archive...
# 100%|██████████| 28.6M/28.6M [00:02<00:00, 12.0MB/s]
# Extracting files...
# Streaming output truncated to the last 5000 lines.
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/42715.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/28473.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/27873.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/8468.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/21757.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/58838.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/34103.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/27863.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/52646.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/33144.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/30308.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/53764.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/59644.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/32648.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17107.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/42458.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/32821.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16342.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/37681.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/21595.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/42946.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/41603.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/38344.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/19212.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/20360.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40755.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/21872.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/51531.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/5137.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43718.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/45450.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/14331.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/57008.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16775.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/47261.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/59817.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36004.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/2787.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/28674.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17529.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/20667.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/9838.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36521.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/34482.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17622.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/49870.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/31107.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/22338.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/34196.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/31337.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/9394.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/14216.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/32491.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/18842.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/35189.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36000.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/27679.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/11202.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/11628.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16261.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/34338.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/59381.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/52180.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/58426.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/42963.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36678.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/49740.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/53841.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/23681.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/35174.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/19696.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/42214.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/31624.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/8318.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/45062.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/41227.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/28597.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/37764.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/30022.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/29292.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/8751.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/13247.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/48030.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/27110.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16884.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/32360.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/57786.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/6162.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/26082.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/21317.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/15244.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/10597.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/3292.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/44104.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/822.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/20750.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36670.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/25046.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/14365.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/51590.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/6092.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/33961.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/30497.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/25044.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/6121.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/22061.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/14843.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/9968.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/24983.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/4329.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/10944.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/20920.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/44509.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/30636.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/13194.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43107.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/59314.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/37265.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/27273.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/31443.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/55856.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/11991.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/8847.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/28260.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/54763.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/15913.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/6661.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/44618.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/50386.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16561.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/27448.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/29349.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/11186.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/33784.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/12739.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40128.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16878.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/58818.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/52214.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/59749.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/10023.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/45381.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/5044.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/26828.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/3696.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/58088.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/44550.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/39613.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/28396.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/20001.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/10529.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/28911.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/25821.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/21516.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/55701.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/18628.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36201.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/2779.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/46973.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/3927.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/12240.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/24478.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43174.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/18828.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/41895.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/58804.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/8301.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36402.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40809.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/53752.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/35641.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17342.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/12257.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/10199.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/18552.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/59695.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43499.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/32152.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/29874.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/39481.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/25258.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/9275.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/11825.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/31939.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/27615.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/31833.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/51713.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/42048.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/19546.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/3818.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/32777.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/45183.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/20196.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/55702.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40876.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/48257.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/49656.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/20254.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/53530.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/13278.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36050.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17737.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/247.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/49669.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/52510.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/53676.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17958.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/26513.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40341.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/58596.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/39134.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/49030.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/5402.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40670.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/8329.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/3277.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/29369.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/5523.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16919.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/54850.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/41040.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/48882.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/1507.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/46032.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/11668.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/27191.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/44592.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/53154.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/18598.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/57638.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/31320.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/59969.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/54038.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/48804.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/33126.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40448.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/7468.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/3173.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/14146.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/59325.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/25478.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/974.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/32891.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/24285.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/53250.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/9481.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40174.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17531.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/11924.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/51843.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/26314.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40264.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/34031.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43253.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/50124.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/58437.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/58961.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/3510.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/52943.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/53126.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/34458.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/57476.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/21510.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/56051.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43663.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/59973.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/39614.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/9051.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/9889.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/26609.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/37111.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/27066.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/6479.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/14934.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/14895.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/20901.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/46831.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/1250.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/900.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/52772.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/11820.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/48708.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/42246.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/24549.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/6078.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17310.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/33141.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16628.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/30694.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16673.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/52184.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/45244.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/55691.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/18885.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/4932.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/12248.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/285.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/28007.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/31299.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/30598.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/58407.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/56133.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/7198.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/35325.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/32451.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/24991.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17019.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/6368.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/38118.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/1884.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/28677.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/3265.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/34930.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/20623.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/31456.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/55573.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/42512.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/11068.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/18756.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/11682.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/7069.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/39016.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/19953.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/12320.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/41483.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/11970.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/39073.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40126.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/50747.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/14922.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/44926.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/44769.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/53661.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/21748.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/41326.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/12059.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/12127.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/18441.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/3786.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/47547.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/3232.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/35332.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/35480.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/18698.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/46784.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36370.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/52311.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/32963.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/1949.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/7171.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16067.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/20450.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/30138.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/9673.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/8750.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/37932.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/19515.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/51329.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/2643.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/7070.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/42492.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/31215.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/10382.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/45086.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/8363.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/53565.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/34688.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/10059.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/37779.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/32970.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/29808.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/47103.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/19393.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/45527.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/1441.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/10387.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/33212.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/55834.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/10706.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17283.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/28448.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/35368.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/50445.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/55496.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/7098.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/53616.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/6272.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/12989.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/14324.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/27163.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/35760.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/38704.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/19558.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/42052.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/45575.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36418.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/595.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/59829.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/14582.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/8563.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/10361.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/12160.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/37737.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/32816.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/35059.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/51584.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/5559.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/19417.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/57895.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/409.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/3190.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/49383.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/19560.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/42017.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/38727.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/13270.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/55803.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/37541.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/2465.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40113.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17186.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/46572.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/58129.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/46659.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/8802.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/29553.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16846.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/27342.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/38154.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43862.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/59084.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/32380.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/7627.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/20792.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/33061.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/27566.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/6010.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/26795.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/57239.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/49495.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/39795.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40317.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/52651.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/50867.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/19860.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/57423.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/44261.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/58703.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/24468.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/54575.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/37593.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43421.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16201.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/12600.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/52845.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/30627.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/49544.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/56178.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/441.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/51012.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/1038.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/35741.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/37951.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/5868.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/59857.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/38005.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/22782.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/38632.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/23327.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/2370.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/5869.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43544.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16814.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/21686.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/12792.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36083.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/37376.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40628.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/3506.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/38293.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40804.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/35387.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/39895.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/27479.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/38992.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/45232.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/59814.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/39724.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/29486.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/34184.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/32860.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/20871.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/27926.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/53950.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/34824.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36991.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/15728.png
# ...
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/54144.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/20130.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17597.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43992.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/58717.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/3533.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/56933.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/21657.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/14182.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/41311.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/46308.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/15607.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/34615.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/10883.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/56431.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/31115.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/56135.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/41251.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/14442.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/27734.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/42516.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/26594.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/46065.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/38775.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/44438.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/11814.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/29565.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/37965.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/15944.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/49599.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/35421.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36225.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/5209.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/33756.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/57551.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36203.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/19933.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/10166.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/51840.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/35127.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/41422.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/41583.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/7381.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/34865.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/31841.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/11912.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16330.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/46123.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36013.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/33899.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/18746.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36832.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/30505.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/13034.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40485.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17323.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43916.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/5745.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/22687.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/41833.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/22664.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/13897.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/1736.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/31923.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40300.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/55295.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/26430.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/22576.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/13096.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/50522.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17793.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/35956.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/11906.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36655.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/13797.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/37702.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40177.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/38829.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/41982.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/42826.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/20811.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16753.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/19163.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/44469.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/32149.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/23285.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/9876.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/3977.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36499.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/49007.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/30237.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/9896.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/29397.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/52883.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/37449.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43416.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/52333.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/34954.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/10208.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43550.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/53438.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/21987.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17142.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/10875.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/32532.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/27231.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/2764.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/18874.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/38748.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/41605.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/29935.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/20594.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/57259.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/41783.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/14015.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/18187.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/57670.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/33313.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/49227.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/9229.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/20264.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43183.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/21876.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/34211.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/37424.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/55992.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/50084.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/48938.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/35191.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/55970.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/26212.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/52127.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/4667.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16877.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/30805.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/33597.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/53146.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/30629.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/35543.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/55468.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17860.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/460.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/10235.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/44962.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/16020.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/626.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/29822.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/32051.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/46701.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/59668.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/14950.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/48290.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/17181.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/26612.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/11515.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/58509.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/40583.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/39034.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43863.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/30500.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/42903.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/59719.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/36481.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/6790.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/43114.png
# /root/.cache/kagglehub/datasets/awsaf49/mnist-dataset/versions/1/mnist_png/training/9/45044.png

# %%
# Load MNIST using Keras (standard approach - KaggleHub provides the same data)
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values to [0, 1] range
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape to include channel dimension: (samples, 28, 28, 1)
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# Create a validation split from training data
x_val = x_train[-10000:]
x_train_split = x_train[:-10000]

print(f"Training set shape:   {x_train_split.shape}")
print(f"Validation set shape: {x_val.shape}")
print(f"Test set shape:       {x_test.shape}")
print(f"Pixel value range:    [{x_train.min():.1f}, {x_train.max():.1f}]")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Training set shape:   (50000, 28, 28, 1)
# Validation set shape: (10000, 28, 28, 1)
# Test set shape:       (10000, 28, 28, 1)
# Pixel value range:    [0.0, 1.0]

# %%
# Visualize some clean MNIST samples
fig, axes = plt.subplots(2, 8, figsize=(16, 4))
fig.suptitle('Clean MNIST Samples', fontsize=16, fontweight='bold')
for i in range(16):
    ax = axes[i//8, i%8]
    ax.imshow(x_train_split[i].squeeze(), cmap='gray')
    ax.set_title(f'Label: {y_train[i]}', fontsize=9)
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3️⃣ Noise Generation & Visualization
# Add Gaussian noise to create corrupted input images. The autoencoder will learn to map these noisy images back to the clean originals.
#
# **Noise Factor:** Controls the intensity of corruption. Higher values = more noise.

# %%
def add_gaussian_noise(images, noise_factor=0.5):
    """Add Gaussian noise to images and clip to valid range [0, 1]."""
    noisy = images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=images.shape)
    return np.clip(noisy, 0.0, 1.0)

# Generate noisy versions of all datasets
noise_factor = 0.5
x_train_noisy = add_gaussian_noise(x_train_split, noise_factor)
x_val_noisy = add_gaussian_noise(x_val, noise_factor)
x_test_noisy = add_gaussian_noise(x_test, noise_factor)

print(f"Noisy training set shape: {x_train_noisy.shape}")
print(f"Noise factor: {noise_factor}")
# Out:
# Noisy training set shape: (50000, 28, 28, 1)
# Noise factor: 0.5

# %%
# Compare clean vs noisy images side-by-side
fig, axes = plt.subplots(3, 8, figsize=(16, 6))
fig.suptitle('Clean vs Noisy MNIST Images (noise_factor=0.5)', fontsize=16, fontweight='bold')

for i in range(8):
    axes[0, i].imshow(x_train_split[i].squeeze(), cmap='gray')
    axes[0, i].axis('off')
    if i == 0: axes[0, i].set_ylabel('Clean', fontsize=12, fontweight='bold')

    axes[1, i].imshow(x_train_noisy[i].squeeze(), cmap='gray')
    axes[1, i].axis('off')
    if i == 0: axes[1, i].set_ylabel('Noisy', fontsize=12, fontweight='bold')

    # Show the noise pattern itself
    noise = x_train_noisy[i] - x_train_split[i]
    axes[2, i].imshow(noise.squeeze(), cmap='RdBu_r', vmin=-0.5, vmax=0.5)
    axes[2, i].axis('off')
    if i == 0: axes[2, i].set_ylabel('Noise', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4️⃣ Denoising Autoencoder Architecture
#
# ### Architecture Design
# - **Encoder:** Conv2D layers with increasing filters (32→64→128) + MaxPooling for spatial compression
# - **Bottleneck:** Compressed latent representation (4×4×128 = 2048 features)
# - **Decoder:** Conv2DTranspose layers to upsample back to original 28×28×1 dimensions
# - **Loss:** MSE (pixel-wise reconstruction loss)
# - **Activation:** ReLU (hidden layers), Sigmoid (output layer to match [0,1] range)

# %%
def build_denoising_autoencoder():
    """Build a Convolutional Denoising Autoencoder using Keras Functional API."""

    # ============ ENCODER ============
    inputs = layers.Input(shape=(28, 28, 1), name='encoder_input')

    # Block 1: 28x28x1 -> 14x14x32
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same', name='enc_conv1')(inputs)
    x = layers.BatchNormalization(name='enc_bn1')(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same', name='enc_conv1b')(x)
    x = layers.MaxPooling2D((2, 2), padding='same', name='enc_pool1')(x)

    # Block 2: 14x14x32 -> 7x7x64
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='enc_conv2')(x)
    x = layers.BatchNormalization(name='enc_bn2')(x)
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='enc_conv2b')(x)
    x = layers.MaxPooling2D((2, 2), padding='same', name='enc_pool2')(x)

    # Block 3: 7x7x64 -> 4x4x128 (bottleneck)
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='enc_conv3')(x)
    x = layers.BatchNormalization(name='enc_bn3')(x)
    encoded = layers.MaxPooling2D((2, 2), padding='same', name='bottleneck')(x)

    # ============ DECODER ============
    # Block 1: 4x4x128 -> 7x7x128
    x = layers.Conv2DTranspose(128, (3, 3), strides=2, activation='relu', padding='same', name='dec_conv1')(encoded)
    x = layers.BatchNormalization(name='dec_bn1')(x)

    # Block 2: 7x7x128 -> 14x14x64
    x = layers.Conv2DTranspose(64, (3, 3), strides=2, activation='relu', padding='same', name='dec_conv2')(x)
    x = layers.BatchNormalization(name='dec_bn2')(x)

    # Block 3: 14x14x64 -> 28x28x32
    x = layers.Conv2DTranspose(32, (3, 3), strides=2, activation='relu', padding='same', name='dec_conv3')(x)
    x = layers.BatchNormalization(name='dec_bn3')(x)

    # Crop from 32x32 back to 28x28 (due to padding) and output layer
    x = layers.Cropping2D(cropping=((2, 2), (2, 2)), name='crop')(x)
    decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same', name='output')(x)

    # Build model
    autoencoder = Model(inputs, decoded, name='Denoising_Autoencoder')
    return autoencoder

# Build and compile the model
autoencoder = build_denoising_autoencoder()
autoencoder.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss='mse',
    metrics=['mae']
)

autoencoder.summary()
# Out:
# Model: "Denoising_Autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder_input (InputLayer)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ enc_conv1 (Conv2D)              │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ enc_bn1 (BatchNormalization)    │ (None, 28, 28, 32)     │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ enc_conv1b (Conv2D)             │ (None, 28, 28, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ enc_pool1 (MaxPooling2D)        │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ enc_conv2 (Conv2D)              │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ enc_bn2 (BatchNormalization)    │ (None, 14, 14, 64)     │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ enc_conv2b (Conv2D)             │ (None, 14, 14, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ enc_pool2 (MaxPooling2D)        │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ enc_conv3 (Conv2D)              │ (None, 7, 7, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ enc_bn3 (BatchNormalization)    │ (None, 7, 7, 128)      │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bottleneck (MaxPooling2D)       │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dec_conv1 (Conv2DTranspose)     │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dec_bn1 (BatchNormalization)    │ (None, 8, 8, 128)      │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dec_conv2 (Conv2DTranspose)     │ (None, 16, 16, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dec_bn2 (BatchNormalization)    │ (None, 16, 16, 64)     │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dec_conv3 (Conv2DTranspose)     │ (None, 32, 32, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dec_bn3 (BatchNormalization)    │ (None, 32, 32, 32)     │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ crop (Cropping2D)               │ (None, 28, 28, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Conv2D)                 │ (None, 28, 28, 1)      │           289 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 380,769 (1.45 MB)
#  Trainable params: 379,873 (1.45 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
# Visualize the model architecture
tf.keras.utils.plot_model(
    autoencoder,
    to_file='autoencoder_architecture.png',
    show_shapes=True,
    show_layer_names=True,
    dpi=100
)
from IPython.display import Image
Image('autoencoder_architecture.png')

# %% [markdown]
# ## 5️⃣ Model Training
# Train the autoencoder with noisy images as **input** and clean images as **target**.

# %%
# Define callbacks for better training
training_callbacks = [
    callbacks.EarlyStopping(
        monitor='val_loss', patience=5, restore_best_weights=True, verbose=1
    ),
    callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1
    )
]

# Train: Input = noisy images, Target = clean images
EPOCHS = 50
BATCH_SIZE = 128

history = autoencoder.fit(
    x_train_noisy, x_train_split,       # noisy input -> clean target
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    shuffle=True,
    validation_data=(x_val_noisy, x_val),  # validate on noisy -> clean
    callbacks=training_callbacks,
    verbose=1
)

print(f"\nTraining completed! Best val_loss: {min(history.history['val_loss']):.6f}")
# Out:
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 31s 36ms/step - loss: 0.0203 - mae: 0.0603 - val_loss: 0.0283 - val_mae: 0.0673 - learning_rate: 0.0010
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.0118 - mae: 0.0403 - val_loss: 0.0121 - val_mae: 0.0385 - learning_rate: 0.0010
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0109 - mae: 0.0381 - val_loss: 0.0121 - val_mae: 0.0385 - learning_rate: 0.0010
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.0104 - mae: 0.0369 - val_loss: 0.0118 - val_mae: 0.0379 - learning_rate: 0.0010
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0100 - mae: 0.0361 - val_loss: 0.0112 - val_mae: 0.0370 - learning_rate: 0.0010
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.0098 - mae: 0.0355 - val_loss: 0.0108 - val_mae: 0.0363 - learning_rate: 0.0010
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0096 - mae: 0.0350 - val_loss: 0.0107 - val_mae: 0.0362 - learning_rate: 0.0010
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0094 - mae: 0.0346 - val_loss: 0.0106 - val_mae: 0.0359 - learning_rate: 0.0010
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0092 - mae: 0.0342 - val_loss: 0.0107 - val_mae: 0.0359 - learning_rate: 0.0010
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0091 - mae: 0.0338 - val_loss: 0.0106 - val_mae: 0.0357 - learning_rate: 0.0010
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0090 - mae: 0.0335 - val_loss: 0.0104 - val_mae: 0.0353 - learning_rate: 0.0010
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0089 - mae: 0.0333 - val_loss: 0.0102 - val_mae: 0.0348 - learning_rate: 0.0010
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 0.0088 - mae: 0.0330 - val_loss: 0.0103 - val_mae: 0.0348 - learning_rate: 0.0010
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 0.0087 - mae: 0.0328 - val_loss: 0.0102 - val_mae: 0.0346 - learning_rate: 0.0010
# Epoch 15/50
# 389/391 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0087 - mae: 0.0327
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 0.0086 - mae: 0.0325 - val_loss: 0.0102 - val_mae: 0.0345 - learning_rate: 0.0010
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 0.0083 - mae: 0.0318 - val_loss: 0.0100 - val_mae: 0.0343 - learning_rate: 5.0000e-04
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 0.0082 - mae: 0.0315 - val_loss: 0.0099 - val_mae: 0.0341 - learning_rate: 5.0000e-04
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0081 - mae: 0.0313 - val_loss: 0.0099 - val_mae: 0.0340 - learning_rate: 5.0000e-04
# Epoch 19/50
# 390/391 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0081 - mae: 0.0313
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0080 - mae: 0.0311 - val_loss: 0.0100 - val_mae: 0.0339 - learning_rate: 5.0000e-04
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0079 - mae: 0.0306 - val_loss: 0.0097 - val_mae: 0.0336 - learning_rate: 2.5000e-04
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0078 - mae: 0.0304 - val_loss: 0.0098 - val_mae: 0.0335 - learning_rate: 2.5000e-04
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0078 - mae: 0.0303 - val_loss: 0.0098 - val_mae: 0.0334 - learning_rate: 2.5000e-04
# Epoch 23/50
# 388/391 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0078 - mae: 0.0303
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0077 - mae: 0.0301 - val_loss: 0.0098 - val_mae: 0.0334 - learning_rate: 2.5000e-04
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0076 - mae: 0.0299 - val_loss: 0.0097 - val_mae: 0.0332 - learning_rate: 1.2500e-04
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0076 - mae: 0.0298 - val_loss: 0.0097 - val_mae: 0.0331 - learning_rate: 1.2500e-04
# Epoch 26/50
# 389/391 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0076 - mae: 0.0299
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0075 - mae: 0.0297 - val_loss: 0.0097 - val_mae: 0.0331 - learning_rate: 1.2500e-04
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0075 - mae: 0.0295 - val_loss: 0.0097 - val_mae: 0.0330 - learning_rate: 6.2500e-05
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0074 - mae: 0.0295 - val_loss: 0.0097 - val_mae: 0.0330 - learning_rate: 6.2500e-05
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0075 - mae: 0.0296
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0074 - mae: 0.0294 - val_loss: 0.0097 - val_mae: 0.0330 - learning_rate: 6.2500e-05
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0074 - mae: 0.0293 - val_loss: 0.0096 - val_mae: 0.0330 - learning_rate: 3.1250e-05
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0074 - mae: 0.0293 - val_loss: 0.0096 - val_mae: 0.0330 - learning_rate: 3.1250e-05
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0074 - mae: 0.0292 - val_loss: 0.0096 - val_mae: 0.0329 - learning_rate: 3.1250e-05
# Epoch 33/50
# 389/391 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0075 - mae: 0.0294
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0074 - mae: 0.0292 - val_loss: 0.0096 - val_mae: 0.0329 - learning_rate: 3.1250e-05
# Epoch 34/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0073 - mae: 0.0292 - val_loss: 0.0096 - val_mae: 0.0330 - learning_rate: 1.5625e-05
# Epoch 35/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0073 - mae: 0.0292 - val_loss: 0.0096 - val_mae: 0.0330 - learning_rate: 1.5625e-05
# Epoch 36/50
# 388/391 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0074 - mae: 0.0293
# Epoch 36: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0073 - mae: 0.0291 - val_loss: 0.0096 - val_mae: 0.0330 - learning_rate: 1.5625e-05
# Epoch 37/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0073 - mae: 0.0291 - val_loss: 0.0096 - val_mae: 0.0330 - learning_rate: 7.8125e-06
# Epoch 38/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0073 - mae: 0.0291 - val_loss: 0.0096 - val_mae: 0.0330 - learning_rate: 7.8125e-06
# Epoch 39/50
# 390/391 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0074 - mae: 0.0293
# Epoch 39: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0073 - mae: 0.0291 - val_loss: 0.0096 - val_mae: 0.0330 - learning_rate: 7.8125e-06
# Epoch 40/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 0.0073 - mae: 0.0291 - val_loss: 0.0096 - val_mae: 0.0330 - learning_rate: 3.9063e-06
# Epoch 41/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0073 - mae: 0.0291 - val_loss: 0.0096 - val_mae: 0.0330 - learning_rate: 3.9063e-06
# Epoch 42/50
# 388/391 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0074 - mae: 0.0292
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0073 - mae: 0.0291 - val_loss: 0.0096 - val_mae: 0.0330 - learning_rate: 3.9063e-06
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0073 - mae: 0.0290 - val_loss: 0.0096 - val_mae: 0.0329 - learning_rate: 1.9531e-06
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0073 - mae: 0.0290 - val_loss: 0.0096 - val_mae: 0.0329 - learning_rate: 1.9531e-06
# Epoch 45/50
# 389/391 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0074 - mae: 0.0292
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1e-06.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0073 - mae: 0.0290 - val_loss: 0.0096 - val_mae: 0.0329 - learning_rate: 1.9531e-06
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0073 - mae: 0.0290 - val_loss: 0.0096 - val_mae: 0.0329 - learning_rate: 1.0000e-06
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0073 - mae: 0.0290 - val_loss: 0.0096 - val_mae: 0.0329 - learning_rate: 1.0000e-06
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0073 - mae: 0.0290 - val_loss: 0.0096 - val_mae: 0.0329 - learning_rate: 1.0000e-06
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0073 - mae: 0.0290 - val_loss: 0.0096 - val_mae: 0.0329 - learning_rate: 1.0000e-06
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0073 - mae: 0.0290 - val_loss: 0.0096 - val_mae: 0.0329 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 46.
#
# Training completed! Best val_loss: 0.009603

# %%
# Plot training history
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Loss curves
axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
axes[0].set_title('Model Loss (MSE)', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch'); axes[0].set_ylabel('Loss')
axes[0].legend(fontsize=12); axes[0].grid(True, alpha=0.3)

# MAE curves
axes[1].plot(history.history['mae'], label='Training MAE', linewidth=2)
axes[1].plot(history.history['val_mae'], label='Validation MAE', linewidth=2)
axes[1].set_title('Mean Absolute Error', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch'); axes[1].set_ylabel('MAE')
axes[1].legend(fontsize=12); axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6️⃣ Evaluation & Denoising Results
# Generate denoised outputs on the test set and compare: **Original → Noisy → Reconstructed**

# %%
# Generate denoised images from noisy test set
denoised_images = autoencoder.predict(x_test_noisy, verbose=1)

# Evaluate quantitative metrics on test set
test_loss, test_mae = autoencoder.evaluate(x_test_noisy, x_test, verbose=0)
print(f"\nTest MSE Loss: {test_loss:.6f}")
print(f"Test MAE:      {test_mae:.6f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
#
# Test MSE Loss: 0.009460
# Test MAE:      0.032591

# %%
# Calculate PSNR (Peak Signal-to-Noise Ratio) and SSIM
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim

psnr_noisy, psnr_denoised = [], []
ssim_noisy, ssim_denoised = [], []

for i in range(len(x_test)):
    orig = x_test[i].squeeze()
    noisy = x_test_noisy[i].squeeze()
    recon = denoised_images[i].squeeze()

    psnr_noisy.append(psnr(orig, noisy))
    psnr_denoised.append(psnr(orig, recon))
    ssim_noisy.append(ssim(orig, noisy, data_range=1.0))
    ssim_denoised.append(ssim(orig, recon, data_range=1.0))

print("=" * 55)
print(f"{'Metric':<20} {'Noisy':>12} {'Denoised':>12} {'Improvement':>12}")
print("=" * 55)
print(f"{'PSNR (dB)':<20} {np.mean(psnr_noisy):>12.2f} {np.mean(psnr_denoised):>12.2f} {np.mean(psnr_denoised)-np.mean(psnr_noisy):>+12.2f}")
print(f"{'SSIM':<20} {np.mean(ssim_noisy):>12.4f} {np.mean(ssim_denoised):>12.4f} {np.mean(ssim_denoised)-np.mean(ssim_noisy):>+12.4f}")
print(f"{'MSE':<20} {np.mean((x_test.squeeze()-x_test_noisy.squeeze())**2):>12.6f} {np.mean((x_test.squeeze()-denoised_images.squeeze())**2):>12.6f}")
print("=" * 55)
# Out:
# =======================================================
# Metric                      Noisy     Denoised  Improvement
# =======================================================
# PSNR (dB)                    9.39        20.65       +11.26
# SSIM                       0.3752       0.8825      +0.5073
# MSE                      0.115483     0.009460
# =======================================================

# %%
# Visualize Original vs Noisy vs Denoised (10 samples)
n_samples = 10
fig, axes = plt.subplots(3, n_samples, figsize=(20, 6))
fig.suptitle('Denoising Autoencoder Results: Original → Noisy → Denoised', fontsize=16, fontweight='bold')

row_labels = ['Original', 'Noisy', 'Denoised']
for i in range(n_samples):
    axes[0, i].imshow(x_test[i].squeeze(), cmap='gray')
    axes[1, i].imshow(x_test_noisy[i].squeeze(), cmap='gray')
    axes[2, i].imshow(denoised_images[i].squeeze(), cmap='gray')
    for j in range(3):
        axes[j, i].axis('off')
    axes[0, i].set_title(f'#{i}', fontsize=9)

for j, label in enumerate(row_labels):
    axes[j, 0].set_ylabel(label, fontsize=12, fontweight='bold', rotation=90, labelpad=15)

plt.tight_layout()
plt.show()

# %%
# Per-digit PSNR analysis
digit_psnr = {d: [] for d in range(10)}
for i in range(len(x_test)):
    digit_psnr[y_test[i]].append(psnr_denoised[i])

avg_psnr = {d: np.mean(v) for d, v in digit_psnr.items()}

plt.figure(figsize=(10, 5))
bars = plt.bar(avg_psnr.keys(), avg_psnr.values(), color=plt.cm.viridis(np.linspace(0.2, 0.8, 10)), edgecolor='black')
plt.xlabel('Digit', fontsize=12); plt.ylabel('Average PSNR (dB)', fontsize=12)
plt.title('Denoising Performance by Digit Class', fontsize=14, fontweight='bold')
plt.xticks(range(10)); plt.grid(axis='y', alpha=0.3)
for bar, val in zip(bars, avg_psnr.values()):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.1, f'{val:.1f}', ha='center', fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7️⃣ Bonus: Advanced Experiments
# ### Experiment 1: Effect of Different Noise Levels
# Test the trained model's robustness across varying noise intensities.

# %%
# Test denoising at different noise levels
noise_levels = [0.1, 0.3, 0.5, 0.7, 0.9]
fig, axes = plt.subplots(len(noise_levels) + 1, 8, figsize=(16, 2.2 * (len(noise_levels) + 1)))

# Show original in first row
for i in range(8):
    axes[0, i].imshow(x_test[i].squeeze(), cmap='gray')
    axes[0, i].axis('off')
axes[0, 0].set_ylabel('Original', fontsize=10, fontweight='bold', rotation=90, labelpad=10)

for row, nf in enumerate(noise_levels, 1):
    noisy = add_gaussian_noise(x_test[:8], nf)
    denoised = autoencoder.predict(noisy, verbose=0)
    for i in range(8):
        # Show top half noisy, bottom half denoised using horizontal concat
        axes[row, i].imshow(denoised[i].squeeze(), cmap='gray')
        axes[row, i].axis('off')
    axes[row, 0].set_ylabel(f'NF={nf}', fontsize=10, fontweight='bold', rotation=90, labelpad=10)

fig.suptitle('Denoised Output Across Different Noise Levels', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Experiment 2: Latent Space Visualization
# Visualize the encoder's compressed representations using t-SNE.

# %%
from sklearn.manifold import TSNE

# Extract encoder part of the model
encoder = Model(autoencoder.input, autoencoder.get_layer('bottleneck').output, name='encoder')

# Get latent representations for a subset of test images
n_viz = 3000
latent_representations = encoder.predict(x_test[:n_viz], verbose=0)
latent_flat = latent_representations.reshape(n_viz, -1)

# Apply t-SNE for 2D visualization
print("Running t-SNE (this may take a moment)...")
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
latent_2d = tsne.fit_transform(latent_flat)

# Plot t-SNE visualization colored by digit class
plt.figure(figsize=(10, 8))
scatter = plt.scatter(latent_2d[:, 0], latent_2d[:, 1], c=y_test[:n_viz],
                      cmap='tab10', alpha=0.6, s=10)
plt.colorbar(scatter, label='Digit Class')
plt.title('t-SNE Visualization of Autoencoder Latent Space', fontsize=14, fontweight='bold')
plt.xlabel('t-SNE Dimension 1'); plt.ylabel('t-SNE Dimension 2')
plt.grid(True, alpha=0.2)
plt.tight_layout()
plt.show()
print("\nDigit clusters show the encoder learns meaningful representations!")
# Out:
# Running t-SNE (this may take a moment)...
# Digit clusters show the encoder learns meaningful representations!

# %% [markdown]
# ### Experiment 3: Reconstruction Error Heatmap
# Visualize pixel-wise reconstruction errors.

# %%
# Show pixel-wise error analysis for select samples
fig, axes = plt.subplots(4, 6, figsize=(15, 10))
fig.suptitle('Pixel-wise Reconstruction Error Analysis', fontsize=16, fontweight='bold')

for i in range(6):
    idx = i * 50  # sample different images
    orig = x_test[idx].squeeze()
    noisy = x_test_noisy[idx].squeeze()
    recon = denoised_images[idx].squeeze()
    error = np.abs(orig - recon)

    axes[0, i].imshow(orig, cmap='gray'); axes[0, i].axis('off')
    axes[1, i].imshow(noisy, cmap='gray'); axes[1, i].axis('off')
    axes[2, i].imshow(recon, cmap='gray'); axes[2, i].axis('off')
    im = axes[3, i].imshow(error, cmap='hot', vmin=0, vmax=0.3); axes[3, i].axis('off')

row_labels = ['Original', 'Noisy', 'Denoised', 'Error Map']
for j, label in enumerate(row_labels):
    axes[j, 0].set_ylabel(label, fontsize=11, fontweight='bold', rotation=90, labelpad=12)

plt.colorbar(im, ax=axes[3, :], orientation='horizontal', fraction=0.05, label='Absolute Error')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8️⃣ Observations & Conclusion
#
# ### Key Observations
#
# 1. **Effective Denoising:** The convolutional autoencoder successfully removes Gaussian noise while preserving the structural integrity of handwritten digits. The PSNR improvement from noisy to denoised images demonstrates clear quantitative gains.
#
# 2. **Architecture Choices:**
#    - **Conv2D + BatchNorm** in the encoder provides stable feature extraction
#    - **Conv2DTranspose** in the decoder enables learnable upsampling (as recommended in the reference repo)
#    - **Sigmoid activation** on the output matches the [0,1] normalized pixel range
#    - **MSE loss** is ideal for pixel-wise reconstruction tasks
#
# 3. **Noise Robustness:** The model trained at noise_factor=0.5 generalizes reasonably well to lower noise levels but degrades at extreme noise (0.9), where most structural information is destroyed.
#
# 4. **Latent Space Quality:** The t-SNE visualization confirms that the encoder learns digit-discriminative features even though it was never given label information — the latent space naturally clusters by digit class.
#
# 5. **Per-Digit Performance:** Simple digits (1, 0) tend to have higher PSNR than complex ones (8, 2), as they have fewer fine details to reconstruct.
#
# 6. **Training Dynamics:** EarlyStopping and ReduceLROnPlateau prevent overfitting and help converge to a better optimum. The validation loss typically plateaus after ~15-25 epochs.
#
# ### Challenges
# - Balancing compression ratio vs reconstruction quality in the bottleneck
# - Conv2DTranspose can introduce checkerboard artifacts (mitigated by BatchNorm)
# - Very high noise levels destroy structural information beyond recovery
#
# ### Future Improvements
# - Try Variational Autoencoder (VAE) for probabilistic denoising
# - Experiment with skip connections (U-Net style) for preserving fine details
# - Add perceptual loss using a pretrained feature extractor
# - Test with salt-and-pepper or speckle noise types

# %%
# Final summary metrics
print("=" * 60)
print("  FINAL RESULTS SUMMARY - Denoising Autoencoder on MNIST")
print("=" * 60)
print(f"  Model Parameters:     {autoencoder.count_params():,}")
print(f"  Training Epochs:      {len(history.history['loss'])}")
print(f"  Final Train Loss:     {history.history['loss'][-1]:.6f}")
print(f"  Final Val Loss:       {history.history['val_loss'][-1]:.6f}")
print(f"  Test MSE:             {test_loss:.6f}")
print(f"  Test MAE:             {test_mae:.6f}")
print(f"  Avg PSNR (noisy):     {np.mean(psnr_noisy):.2f} dB")
print(f"  Avg PSNR (denoised):  {np.mean(psnr_denoised):.2f} dB")
print(f"  Avg SSIM (noisy):     {np.mean(ssim_noisy):.4f}")
print(f"  Avg SSIM (denoised):  {np.mean(ssim_denoised):.4f}")
print("=" * 60)
print("  ✅ Denoising autoencoder successfully trained and evaluated!")
print("=" * 60)
# Out:
# ============================================================
#   FINAL RESULTS SUMMARY - Denoising Autoencoder on MNIST
# ============================================================
#   Model Parameters:     380,769
#   Training Epochs:      50
#   Final Train Loss:     0.007289
#   Final Val Loss:       0.009604
#   Test MSE:             0.009460
#   Test MAE:             0.032591
#   Avg PSNR (noisy):     9.39 dB
#   Avg PSNR (denoised):  20.65 dB
#   Avg SSIM (noisy):     0.3752
#   Avg SSIM (denoised):  0.8825
# ============================================================
#   ✅ Denoising autoencoder successfully trained and evaluated!
# ============================================================
